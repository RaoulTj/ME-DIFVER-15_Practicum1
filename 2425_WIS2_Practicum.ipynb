# %% [markdown]
# # PRACTICUM WISKUNDE 2

# %%
from ipywidgets import *
import ipywidgets as widgets
from fractions import Fraction
from sympy import *
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


import plotly as py 
import plotly.graph_objs as go 
py.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
x, y, z, dy, dx, C, expo = symbols('x y z dy dx C e ')

# %% [markdown]
# <hr style="border:2px solid #9EA700">

# %% [markdown]
# ## 1. LIMIETEN

# %% [markdown]
# ### Opdracht 1.1

# %% [markdown]
# Bereken:
#
# $$
# \lim_{x \to 2} \dfrac{x^2-4}{x-2}
# $$

# %% [markdown]
# Vul hieronder de code in:

# %% [markdown]
# ### Opdracht 1.2

# %% [markdown]
# Bereken:
#
# $$
# \lim_{x \to 0} \dfrac{\sin(x)}{x}
# $$

# %% [markdown]
# Vul hieronder de code in:

# %% [markdown]
# ### Opdracht 1.3

# %% [markdown]
# Bereken:
#
# $$
# \lim_{x \to \infty} \dfrac{2x^2+3}{x^2-5}
# $$

# %% [markdown]
# Vul hieronder de code in:

# %% [markdown]
# <hr style="border:1px solid #9EA700">

# %% [markdown]
# ## 2. DIFFERENTIËREN

# %% [markdown]
# ### Opdracht 2.1

# %% [markdown]
# Bepaal de extreme waarde(n) van deze functie:
#
# $$
# f(x) = x^3 - 6x^2 +9x
# $$

# %% [markdown]
# Vul hieronder de code in:

# %%
# x-waarden
x = np.linspace(-1, 5, 500)

# %%
# functies
f = @@@@@@@
fp = @@@@
# Out:
#   Cell In[428], line 2
#     f = @@@@@@@
#         ^
# SyntaxError: invalid syntax

# %%
# figure maken
fig = go.Figure()

# f(x)
fig.add_trace(go.Scatter(
    x=x,
    y=f,
    mode='lines',
    name='f(x) = x³ - 6x² + 9x'
))

# f'(x)
fig.add_trace(go.Scatter(
    x=x,
    y=fp,
    mode='lines',
    name="f'(x) = 3x² - 12x + 9"
))

# layout
fig.update_layout(
    title="Grafiek van f(x) en f'(x)",
    width=1000,
    height=700,
    xaxis=dict(
        title='x',
        range=[-1, 5]
    ),
    yaxis=dict(
        title='y',
        range=[-10, 15]
    )
)

# tonen
fig.show()

# %% [markdown]
# <hr style="border:1px solid #9EA700">

# %% [markdown]
# ## 3. TAYLOR REEKSEN

# %%
x = symbols('x')

# %% [markdown]
# ### Opgave 3.1

# %% [markdown]
# Bereken de 3e orde Taylor reeks rond $x=1$
#
# $$
# f(x)=\ln(x)
# $$

# %% [markdown]
# Vul hieronder de code in:

# %% [markdown]
# ### Opgave 3.2

# %% [markdown]
# Bereken de 3e orde Taylor reeks rond $x=4$
#
# $$
# g(x)=\sqrt{x}
# $$

# %% [markdown]
# Vul hieronder de code in:

# %% [markdown]
# ### Opgave 3.3

# %% [markdown]
# Bereken de 3e orde Taylor reeks rond $x=1$
#
# $$
# h(x)=e^x
# $$

# %% [markdown]
# Vul hieronder de code in:

# %% [markdown]
# Plot de grafieken:

# %%
import numpy as np
import plotly.graph_objects as go

# x-waarden
x = np.linspace(0.2, 10, 5000)

# echte functie
f = @@@@@@

# Taylorbenadering rond x = 1
taylor = (
   @@@@@@@
)

# figure
fig = go.Figure()

# ln(x)
fig.add_trace(go.Scatter(
    x=x,
    y=f,
    mode='lines',
    name='ln(x)'
))

# ontwikkelpunt x = 1
fig.add_trace(go.Scatter(
    x=[1],
    y=[np.log(1)],
    mode='markers',
    name='Ontwikkelpunt'
))

# Taylor
fig.add_trace(go.Scatter(
    x=x,
    y=taylor,
    mode='lines',
    name='Taylor rond x=1'
))

# layout
fig.update_layout(
    title='ln(x) en Taylorbenadering',
    width=1000,
    height=700,

    xaxis=dict(
        title='x',
        range=[0, 2]
    ),

    yaxis=dict(
        title='y',
        range=[-2, 1]
    )
)

fig.show()

# %%
import numpy as np
import plotly.graph_objects as go

# x-waarden
x = np.linspace(0, 50, 5000)

# echte functie
f = @@@@@

# 3e orde Taylorreeks rond x = 4
taylor = (
  @@@@@
)

# figure
fig = go.Figure()

# sqrt(x)
fig.add_trace(go.Scatter(
    x=x,
    y=f,
    mode='lines',
    name='sqrt(x)'
))

# ontwikkelpunt x = 4
fig.add_trace(go.Scatter(
    x=[4],
    y=[2],
    mode='markers',
    name='Ontwikkelpunt'
))

# Taylorreeks
fig.add_trace(go.Scatter(
    x=x,
    y=taylor,
    mode='lines',
    name='Taylor rond x=4'
))

# layout
fig.update_layout(
    title='sqrt(x) en Taylorreeks rond x=4',
    width=1000,
    height=700,

    xaxis=dict(
        title='x',
        range=[2, 6]
    ),

    yaxis=dict(
        title='y',
        range=[1.2, 2.6]
    )
)

fig.show()

# %%
import numpy as np
import plotly.graph_objects as go

# x-waarden
x = np.linspace(-1, 3, 500)

# echte functie
f = @@@@@@@

# 4e orde Taylorreeks rond x = 1
taylor = (
@@@@@@
)

# figure
fig = go.Figure()

# e^x
fig.add_trace(go.Scatter(
    x=x,
    y=f,
    mode='lines',
    name='e^x'
))

# Taylorreeks
fig.add_trace(go.Scatter(
    x=x,
    y=taylor,
    mode='lines',
    name='Taylor rond x=1'
))
import numpy as np
import plotly.graph_objects as go

# x-waarden
x = np.linspace(-1, 3, 500)

# echte functie
f = np.exp(x)

# 4e orde Taylorreeks rond x = 1
taylor = (
    np.e
    + np.e*(x - 1)
    + np.e*(x - 1)**2 / 2
    + np.e*(x - 1)**3 / 6
    + np.e*(x - 1)**4 / 24
)

# figure
fig = go.Figure()

# e^x
fig.add_trace(go.Scatter(
    x=x,
    y=f,
    mode='lines',
    name='e^x'
))

# Taylorreeks
fig.add_trace(go.Scatter(
    x=x,
    y=taylor,
    mode='lines',
    name='Taylor rond x=1'
))

# ontwikkelpunt
fig.add_trace(go.Scatter(
    x=[1],
    y=[np.e],
    mode='markers',
    name='Ontwikkelpunt'
))

# layout
fig.update_layout(
    title='e^x en Taylorreeks rond x=1',
    width=1000,
    height=700,

    xaxis=dict(
        title='x',
        range=[-1, 3]
    ),

    yaxis=dict(
        title='y',
        range=[0, 25]
    )
)

fig.show()

# %% [markdown]
# <hr style="border:1px solid #9EA700">

# %% [markdown]
# ## 4. INTEGREREN

# %%
x = symbols('x')

# %% [markdown]
# ### Opdracht 4.1

# %% [markdown]
# Bereken
#
# $$
# \int_0^2 x^2 dx
# $$

# %% [markdown]
# Vul hieronder de code in:

# %% [markdown]
# ### Opdracht 4.2

# %% [markdown]
# Bereken
#
# $$
# \int_{-1}^1 e^{-x^2} dx
# $$

# %% [markdown]
# Vul hieronder de code in:

# %% [markdown]
# ## 5. COMPLEXE GETALLEN

# %% [markdown]
# ### Opdracht 5.1

# %% [markdown]
# Los deze vergelijking op:
#
# $$
# (z+2i)^3 = 64i
# $$
